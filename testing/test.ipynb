# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\karti\\projects\\hashtune\\hashtag_stats.csv")

# %%
df.head()
# Out:
#   name  postsCount                                         url   id    posts  \
# 0  cat   308900000  https://www.instagram.com/explore/tags/cat  cat  308.9 M
#
#   postsPerDay  difficulty                                            related  \
# 0     38.55 K         NaN  [{'hash': '#catsofinstagram', 'info': '212.55 ...
#
#                                             frequent  \
# 0  [{'hash': '#cats', 'info': '165.61 m'}, {'hash...
#
#                                              average  \
# 0  [{'hash': '#total_catalunya', 'info': '988.91 ...
#
#                                                 rare  \
# 0  [{'hash': '#catalunya_arquitectura', 'info': '...
#
#                                      relatedFrequent  \
# 0  [{'hash': '#love', 'info': '2.15 g'}, {'hash':...
#
#                                       relatedAverage  \
# 0  [{'hash': '#mammal', 'info': '721.59 k'}, {'ha...
#
#                                          relatedRare  \
# ...

# %%
df.frequent[0]
# Out:
# "[{'hash': '#cats', 'info': '165.61 m'}, {'hash': '#education', 'info': '54.47 m'}, {'hash': '#cats_of_instagram', 'info': '35.32 m'}, {'hash': '#cats_of_world', 'info': '14.45 m'}, {'hash': '#catalunya', 'info': '12.67 m'}, {'hash': '#excellent_cats', 'info': '3.74 m'}, {'hash': '#cats_of_day', 'info': '3.14 m'}, {'hash': '#cats🐱', 'info': '2.7 m'}, {'hash': '#cats_of_instworld', 'info': '1.97 m'}, {'hash': '#ok_catalunya', 'info': '1.61 m'}, {'hash': '#raconsde_catalunya', 'info': '1.5 m'}]"

# %%
import json

# %%
list_doc = json.loads(df.topPosts[0])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 list_doc = json.loads(df.topPosts[0])
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.10-windows-x86_64-none\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Roaming\uv\python\cpython-3.11.10-windows-x86_64-none\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...

# %%
import ast

# %%
data_string = ast.literal_eval(df.topPosts[0])

# %%
data_string
# Out:
# [{'inputUrl': 'https://www.instagram.com/explore/tags/cat',
#   'id': '3724166086377251196',
#   'type': 'Sidecar',
#   'shortCode': 'DOu5VL3EqF8',
#   'caption': '📽 from 571325796 | DY\n#catloversclub',
#   'hashtags': ['catloversclub'],
#   'mentions': [],
#   'url': 'https://www.instagram.com/p/DOu5VL3EqF8/',
#   'commentsCount': 60,
#   'firstComment': '',
#   'latestComments': [],
#   'dimensionsHeight': 960,
#   'dimensionsWidth': 720,
# ...

# %%
data_dict = json.dumps(data_string)

# %%
data_dict
# Out:
# '[{"inputUrl": "https://www.instagram.com/explore/tags/cat", "id": "3724166086377251196", "type": "Sidecar", "shortCode": "DOu5VL3EqF8", "caption": "\\ud83d\\udcfd from 571325796 | DY\\n#catloversclub", "hashtags": ["catloversclub"], "mentions": [], "url": "https://www.instagram.com/p/DOu5VL3EqF8/", "commentsCount": 60, "firstComment": "", "latestComments": [], "dimensionsHeight": 960, "dimensionsWidth": 720, "displayUrl": "https://scontent-vie1-1.cdninstagram.com/v/t51.2885-15/550411700_18533801386055469_3379100731216463869_n.jpg?stp=dst-jpg_e15_p360x360_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6IkNBUk9VU0VMX0lURU0uaW1hZ2VfdXJsZ2VuLjcyMHg5NjAuc2RyLmY4Mjc4Ny5kZWZhdWx0X2NvdmVyX2ZyYW1lLmMyIn0&_nc_ht=scontent-vie1-1.cdninstagram.com&_nc_cat=1&_nc_oc=Q6cZ2QG2h6nTxq8np0bJsWip_CXmI_nU9mcXKO_XSMo9dMThDWLLzkvbu5hqyzmr9i7M-eQ&_nc_ohc=cfVufKAOa3IQ7kNvwHurAaG&_nc_gid=eqIBPP1ApmB1QPm_nVryKQ&edm=AGyKU4gBAAAA&ccb=7-5&ig_cache_key=MzcyNDE2NTg5MTYxMDUxMjk2Mw%3D%3D.3-ccb7-5&oh=00_AfYucaZpwCjWBN8yNvl0JKIhv_W1cxjwDn
# ...

# %%
data_dict_again = json.loads(data_dict)

# %%
data_dict_again = data_dict_again[0:5]

# %%
len(data_dict_again)
# Out:
# 5

# %%
data_dict_again[0].keys()
# Out:
# dict_keys(['inputUrl', 'id', 'type', 'shortCode', 'caption', 'hashtags', 'mentions', 'url', 'commentsCount', 'firstComment', 'latestComments', 'dimensionsHeight', 'dimensionsWidth', 'displayUrl', 'images', 'likesCount', 'timestamp', 'childPosts', 'ownerFullName', 'ownerUsername', 'ownerId', 'productType', 'isSponsored', 'musicInfo'])

# %%
keys_to_keep = ["type", "caption", "hashtags"]

# %%
new_dict = [
    {k: d[k] for k in keys_to_keep}
    for d in data_dict_again
]

# %%
new_hashtags = set()

# %%
for data in new_dict:
    new_hashtags.update(data["hashtags"])

# %%
len(new_hashtags)
# Out:
# 74

# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %%
posts_df = pd.read_csv("C:\\Users\\karti\\projects\\hashtune\\posts.csv")

# %%
posts_df.head()
# Out:
#                     id     type    shortCode  \
# 0  3724709639738488669  Sidecar  DOw067YFfdd
# 1  3724597069735932815    Video  DOwbU0ZEjOP
# 2  3724651546471990076  Sidecar  DOwntjzkoM8
# 3  3678716934050027865    Video  DMNbY-TRBlZ
# 4  3724800192303926209    Image  DOxJgpBlQvB
#
#                                              caption  \
# 0  What if the search for Cleopatra's final resti...
# 1  From taking risks and striving for flow state,...
# 2  Once hailed as a “miracle material,” the reali...
# 3  With cutting-edge science on his side, @chrish...
# 4  Photo by Jason Gulley @jason_gulley_science | ...
#
#                           hashtags  \
# 0        ['CleopatrasFinalSecret']
# 1  ['LimitlessWithChrisHemsworth']
# 2               ['SubscriberWeek']
# 3  ['LimitlessWithChrisHemsworth']
# 4                               []
#
#                                             mentions  \
# 0  ['DisneyPlus', 'hulu.', 'kennethgarrettphoto',...
# ...
